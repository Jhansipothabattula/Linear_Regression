# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to RNNs

# %% [markdown]
# * **Basic Concepts of RNNs**
#   * Sequential Data
#   * Temporal Dependency
#   * Vanishing Gradient Problem
#
#
# * **Architecture of RNNs**
#   * Recurrent Connections
#   * Hidden State
#   * Output
#
#
# * **Types of RNNs**
#   * One-to-One
#   * One-to-Many
#   * Many-to-One
#   * Many-to-Many (Sequence-to-Sequence)
#
#
# * **Long Short-Term Memory (LSTM) and Gated Recurrent Units (GRUs)**
#   * LSTM
#   * GRU
#
#
# * **Training RNNs**
#   * Backpropagation Through Time (BPTT)
#   * Gradient Clipping
#   * Regularization
#
#
# * **Applications of RNNs**
#   * Natural Language Processing
#   * Speech Recognition
#   * Time Series Analysis
