# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day138.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model Validation, Transform and Serving with TFX

# %% [markdown]
# **Model Validation, Transform, and Serving with TFX**
#
# 1. Model Validation
#     * Evaluator Component
#     * Evaluation Metrics
#     * Visualization and Analysis
#
#
# 2. Data Transformation
#     * Transform Component
#     * Schema Inference
#     * Custom Transformations
#
#
# 3. Model Serving
#     * Pusher Component
#     * Model Versioning
#     * Monitoring and Management
