# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Graphs and Sessions

# %% [markdown]
# **TensorFlow Compuational Graph**
#
# - 1. What is a Computational Graph?
#
#   - Definition
#
#   - Nodes
#
#   - Edges
#
# - 2. Building a Compuational Graph
#
#   - Define Operations
#
#   - Create Tensors
#
#   - Connect Operations
#
# - 3. Visulaizing the Computational Graph?
#
#   - TensorBoard
#
#   - tf.summary.FileWriter
#
# - 4. Executing the computing Graph
#
#   - Session Execution
#
# - 5. Benefits of Computational Graphs
#
#   - 1. Optimization
#
#   - 2. Portability
#
#   - 3. Debugging

# %%
import tensorflow as tf

# Define Operations
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([[5, 6], [7, 8]])
c = tf.matmul(a, b)

# Print the computational graph
print(tf.compat.v1.get_default_graph().as_graph_def())

with tf.compat.v1.Session() as sess:
  writer = tf.compat.v1.summary.FileWriter(logdir="logs", graph=sess.graph)
  writer.close()
# Out:
# versions {
#   producer: 2129
# }
