# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day134.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TensorFlow's Distributed Execution Framework

# %% [markdown]
# * **Distributed Execution Engine**
#   * Distributed Sessions
#   * Distributed Optimizers
#   * Fault Tolerance
#
#
# * **Distributed Training Strategies**
#   * Data Parallelism
#   * Model Parallelism
#   * Pipeline Parallelism
#
#
# * **Deployment and Configuration**
#   * tf.distribute.Strategy
#   * TensorFlow Extended (TFX)
