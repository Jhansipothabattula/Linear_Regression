# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day136.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to TFX

# %% [markdown]
# **TensorFlow Extended: Introduction to TFX**
#
# **Key Components of TFX**
#
# * **TFX Pipeline**
# * **TFX Components**
#   * ExampleGen
#   * StatisticsGen
#   * SchemaGen
#   * ExampleValidator
#   * Transform
#   * Trainer
#   * Evaluator
#   * Pusher
#
#
# * **TFX Orchestration**
# * **TFX Metadata Store**
#
#
# **Features of TFX**
#
#   * **End-to-End Automation**
#   * **Scalability and Robustness**
#   * **Customizability and Extensibility**
#   * **Monitoring and Governance**
#
# **Deployment and Integration**
