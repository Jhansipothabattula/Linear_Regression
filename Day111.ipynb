# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensorflow vs Other Machine Learning Frameworks

# %% [markdown]
# **Tensorflow| PyTorch| Keras| Scikit-learn**

# %% [markdown]
# - Ease of Use
# - Perfomance
# - Community and Ecosystem
# - Model Deployment

# %% [markdown]
# **Strengths and Weakness of Tensorflow**
#
# - Strengths of Tensorflow
#
#   - Scalability
#
#   - Flexibility
#
#   - Rich Ecosystem
#
#   - Production Ready
#
#   - Integration with Google Products
#
# - Weakness of Tensorflow
#
#   - Steep Learning curve
#
#   - Complexity
#
#   - Debugging and Visualization
#
#   - Deployment Overhead
#
#   - Competition

# %% [markdown]
# **Use cases where TensorFlow excels**
#
# - Computer Vision
#
#   - Image Classification
#
#   - Object Detection
#
#   - Image Segmentation
#
# - Speech Recognition and Generation
#
#   - Speech Recognition
#
#   - Speech Synthesis
#
# - Time Series Analysis
#
#   - Forecasting
#
#   - Anomaly Detection
#
# - Natural Language Processing(NLP)
#
#   - Text Classification
#
#   - Named Entity Recognition(NER)
#
#   - Machine Translation
#
# - Recommender Systems
#
#   - Collaborative Filtering
#
#   - Content-based Filtering
#
# - Reinforcement Learning
#
#   - Game Playing
#
#   - Control Systems
