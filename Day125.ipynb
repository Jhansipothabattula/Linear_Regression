# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building and Training CNNs with TensorFlow

# %% [markdown]
# ### **1. Import TensorFlow and Keras**
#
# ```python
# import tensorflow as tf
# from tensorflow.keras import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
#
# ```
#
# ---
#
# ### **2. Define the Model Architecture**
#
# ```python
# model = Sequential([
#     Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
#     MaxPooling2D(pool_size=(2, 2)),
#     Conv2D(64, kernel_size=(3, 3), activation='relu'),
#     MaxPooling2D(pool_size=(2, 2)),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(10, activation='softmax')
# ])
#
# ```
#
# ---
#
# ### **3. Compile the Model**
#
# ```python
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#
# ```
#
# ---
#
# ### **4. Load and Preprocess Data**
#
# ```python
# # Load and preprocess dataset (replace with your dataset)
# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# x_train = x_train.reshape((-1, 28, 28, 1)).astype('float32') / 255.0
# x_test = x_test.reshape((-1, 28, 28, 1)).astype('float32') / 255.0
#
# ```
#
# ---
#
# ### **5. Train the Model**
#
# ```python
# model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
#
# ```
#
# ---
#
# ### **6. Evaluate the Model**
#
# ```python
# test_loss, test_accuracy = model.evaluate(x_test, y_test)
# print("Test Loss:", test_loss)
# print("Test Accuracy:", test_accuracy)
#
# ```
