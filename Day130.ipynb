# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhansipothabattula/Machine_Learning/blob/main/Day130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Saving and Loading Models

# %% [markdown]
# # Saving Models
# * **Save Entire Model**
# ```python
# # Save entire model to HDF5 file
# model.save("model.h5")
#
# ```
#
#
# * **Save Model Architecture and Weights Separately**
# ```python
# # Save model architecture to JSON file
# with open("model.json", "w") as json_file:
#     json_file.write(model.to_json())
#
# # Save model weights to HDF5 file
# model.save_weights("model_weights.h5")
#
# ```
#
#
# # Loading Models
#
# * **Loading Models**
# * **Load Entire Model**
# ```python
# from tensorflow.keras.models import load_model
#
# # Load entire model from HDF5 file
# loaded_model = load_model("model.h5")
#
# ```
#
#
# * **Load Model Architecture and Weights Separately**
# ```python
# from tensorflow.keras.models import model_from_json
#
# # Load model architecture from JSON file
# with open("model.json", "r") as json_file:
#     loaded_model_json = json_file.read()
# loaded_model = model_from_json(loaded_model_json)
#
# # Load model weights from HDF5 file
# loaded_model.load_weights("model_weights.h5")
#
# ```

# %% [markdown]
# **Saving and Loading Models**
#
# - Model Complexity
#
# - Model Serialization Options
